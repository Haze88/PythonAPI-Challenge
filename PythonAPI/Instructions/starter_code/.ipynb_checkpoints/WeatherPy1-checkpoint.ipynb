# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create url and indicate imperial 
url ="http://api.openweathermap.org/data/2.5/weather?"
units ="imperial"

# %%
#Build a partial
query = f"{url}appid={weather_api_key}&units={units}&q="

# %%
#Create extracts for temp, humidity, cloudiness, and wind speed
latitude =[]
longitude =[]
temperature =[]
humidity =[]
cloudiness =[]
wind_speed=[]
dates=[]

for x in range(len(cities)):
    response = requests.get(f"{query}{cities[x]}").json()
    
    # Some of the cities we generate don't have data in openweathermap, so set their values to numpy's NaN
    try:
        temperature.append(response['main']['temp_max'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        dates.append(response['dt'])
    except KeyError:
        temperature.append(np.nan)
        latitude.append(np.nan)
        longitude.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        dates.append(np.nan)
    
    # Sometimes it's not cloudy! Then 'clouds' does not exist, so set it to zero.
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
        cloudiness.append(0)
        
    # Print each city name and query string    
    print(f"Processing record {x + 1} | {cities[x]}")
    print(f"{query}{cities[x]}")

print("--------------------------------------------")
print("Data Processing Complete")
print("--------------------------------------------")

# Assemble everything into a data frame
weather_df = pd.DataFrame({"City": cities,
                           "Latitude": latitude,
                           "Longitude": longitude,
                           "Humidity": humidity,
                           "Max Temp": temperature,
                           "Cloudiness": cloudiness,
                           "Wind Speed": wind_speed,
                           "Date": dates,
                          })
# Out:
# Processing record 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=saint george
# Processing record 2 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=mataura
# Processing record 3 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=port lincoln
# Processing record 4 | dedougou
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=dedougou
# Processing record 5 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=butaritari
# Processing record 6 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=rikitea
# Processing record 7 | ossora
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ossora
# Processing record 8 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=illoqqortoormiut
# Processing record 9 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=avarua
# Processing record 10 | grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=grindavik
# Processing record 11 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=castro
# Processing record 12 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=tuktoyaktuk
# Processing record 13 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=qaanaaq
# Processing record 14 | tyssedal
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=tyssedal
# Processing record 15 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=busselton
# Processing record 16 | do gonbadan
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=do gonbadan
# Processing record 17 | sorvag
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=sorvag
# Processing record 18 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=saint anthony
# Processing record 19 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=puerto ayora
# Processing record 20 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=hobart
# Processing record 21 | samusu
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=samusu
# Processing record 22 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=new norfolk
# Processing record 23 | gorno-chuyskiy
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=gorno-chuyskiy
# Processing record 24 | chabahar
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=chabahar
# Processing record 25 | ormond beach
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ormond beach
# Processing record 26 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=taolanaro
# Processing record 27 | lyuban
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=lyuban
# Processing record 28 | diebougou
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=diebougou
# Processing record 29 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=cape town
# Processing record 30 | valle de allende
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=valle de allende
# Processing record 31 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=lebu
# Processing record 32 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ushuaia
# Processing record 33 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=saint-philippe
# Processing record 34 | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=la ronge
# Processing record 35 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=bredasdorp
# Processing record 36 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=atuona
# Processing record 37 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kapaa
# Processing record 38 | lagos
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=lagos
# Processing record 39 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=albany
# Processing record 40 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=tasiilaq
# Processing record 41 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ancud
# Processing record 42 | kawit
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kawit
# Processing record 43 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=talnakh
# Processing record 44 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=hilo
# Processing record 45 | ibirataia
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ibirataia
# Processing record 46 | tigbao
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=tigbao
# Processing record 47 | viedma
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=viedma
# Processing record 48 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=east london
# Processing record 49 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=coquimbo
# Processing record 50 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=bethel
# Processing record 51 | malinao
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=malinao
# Processing record 52 | temaraia
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=temaraia
# Processing record 53 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=provideniya
# Processing record 54 | paita
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=paita
# Processing record 55 | rimouski
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=rimouski
# Processing record 56 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=mahebourg
# Processing record 57 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=port alfred
# Processing record 58 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=hithadhoo
# Processing record 59 | calabozo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=calabozo
# Processing record 60 | eidsvag
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=eidsvag
# Processing record 61 | aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=aklavik
# Processing record 62 | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=constitucion
# Processing record 63 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=saskylakh
# Processing record 64 | daia
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=daia
# Processing record 65 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=carnarvon
# Processing record 66 | baghdad
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=baghdad
# Processing record 67 | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=hofn
# Processing record 68 | beba
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=beba
# Processing record 69 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=tsihombe
# Processing record 70 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=longyearbyen
# Processing record 71 | nyurba
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=nyurba
# Processing record 72 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=dunedin
# Processing record 73 | wagar
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=wagar
# Processing record 74 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=cherskiy
# Processing record 75 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=tuatapere
# Processing record 76 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=santa rosa
# Processing record 77 | miracema do tocantins
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=miracema do tocantins
# Processing record 78 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=mogadishu
# Processing record 79 | borgarnes
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=borgarnes
# Processing record 80 | weligama
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=weligama
# Processing record 81 | nalut
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=nalut
# Processing record 82 | nizhniy kuranakh
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=nizhniy kuranakh
# Processing record 83 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=lagoa
# Processing record 84 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=chuy
# Processing record 85 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=sentyabrskiy
# Processing record 86 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=norman wells
# Processing record 87 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=pevek
# Processing record 88 | susanville
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=susanville
# Processing record 89 | korla
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=korla
# Processing record 90 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=vila velha
# Processing record 91 | cumaribo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=cumaribo
# Processing record 92 | wadowice
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=wadowice
# Processing record 93 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=severo-kurilsk
# Processing record 94 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=pangnirtung
# Processing record 95 | camana
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=camana
# Processing record 96 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=vaini
# Processing record 97 | gubkinskiy
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=gubkinskiy
# Processing record 98 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=mar del plata
# Processing record 99 | phan rang
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=phan rang
# Processing record 100 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=faanui
# Processing record 101 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=nizhneyansk
# Processing record 102 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=punta arenas
# Processing record 103 | margate
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=margate
# Processing record 104 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=sao filipe
# Processing record 105 | harper
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=harper
# Processing record 106 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=bluff
# Processing record 107 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=jamestown
# Processing record 108 | krasnoborsk
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=krasnoborsk
# Processing record 109 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=belushya guba
# Processing record 110 | juneau
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=juneau
# Processing record 111 | oranjestad
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=oranjestad
# Processing record 112 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=hermanus
# Processing record 113 | bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=bilibino
# Processing record 114 | loa janan
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=loa janan
# Processing record 115 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=clyde river
# Processing record 116 | kemijarvi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kemijarvi
# Processing record 117 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=isangel
# Processing record 118 | naryan-mar
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=naryan-mar
# Processing record 119 | syava
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=syava
# Processing record 120 | formoso do araguaia
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=formoso do araguaia
# Processing record 121 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=barrow
# Processing record 122 | rabaul
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=rabaul
# Processing record 123 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=souillac
# Processing record 124 | inhambane
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=inhambane
# Processing record 125 | saryg-sep
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=saryg-sep
# Processing record 126 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=antofagasta
# Processing record 127 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=port elizabeth
# Processing record 128 | sao sebastiao
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=sao sebastiao
# Processing record 129 | pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=pangkalanbuun
# Processing record 130 | talaya
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=talaya
# Processing record 131 | soderhamn
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=soderhamn
# Processing record 132 | kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kununurra
# Processing record 133 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=iqaluit
# Processing record 134 | muros
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=muros
# Processing record 135 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=thompson
# Processing record 136 | burica
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=burica
# Processing record 137 | hinesville
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=hinesville
# Processing record 138 | logrono
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=logrono
# Processing record 139 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kruisfontein
# Processing record 140 | rivers
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=rivers
# Processing record 141 | andevoranto
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=andevoranto
# Processing record 142 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ponta do sol
# Processing record 143 | north platte
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=north platte
# Processing record 144 | hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=hobyo
# Processing record 145 | aswan
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=aswan
# Processing record 146 | taltal
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=taltal
# Processing record 147 | asuncion
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=asuncion
# Processing record 148 | karamay
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=karamay
# Processing record 149 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=arraial do cabo
# Processing record 150 | yangambi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=yangambi
# Processing record 151 | ndola
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ndola
# Processing record 152 | college
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=college
# Processing record 153 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=nanortalik
# Processing record 154 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=puerto escondido
# Processing record 155 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kodiak
# Processing record 156 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=mitsamiouli
# Processing record 157 | kindu
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kindu
# Processing record 158 | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=flinders
# Processing record 159 | kutum
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kutum
# Processing record 160 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=vestmannaeyjar
# Processing record 161 | charlestown
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=charlestown
# Processing record 162 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=codrington
# Processing record 163 | teguldet
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=teguldet
# Processing record 164 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=caravelas
# Processing record 165 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=sao joao da barra
# Processing record 166 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=katsuura
# Processing record 167 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=lompoc
# Processing record 168 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=umzimvubu
# Processing record 169 | sokolka
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=sokolka
# Processing record 170 | nortelandia
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=nortelandia
# Processing record 171 | ngukurr
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ngukurr
# Processing record 172 | braganca paulista
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=braganca paulista
# Processing record 173 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=alofi
# Processing record 174 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=khatanga
# Processing record 175 | biu
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=biu
# Processing record 176 | ratnagiri
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ratnagiri
# Processing record 177 | serowe
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=serowe
# Processing record 178 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=grand river south east
# Processing record 179 | ankazobe
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ankazobe
# Processing record 180 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=chokurdakh
# Processing record 181 | christchurch
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=christchurch
# Processing record 182 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=torbay
# Processing record 183 | hannibal
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=hannibal
# Processing record 184 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=komsomolskiy
# Processing record 185 | yuzhno-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=yuzhno-yeniseyskiy
# Processing record 186 | uribia
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=uribia
# Processing record 187 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=dikson
# Processing record 188 | moose factory
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=moose factory
# Processing record 189 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=geraldton
# Processing record 190 | tatarbunary
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=tatarbunary
# Processing record 191 | hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=hambantota
# Processing record 192 | haines junction
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=haines junction
# Processing record 193 | amderma
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=amderma
# Processing record 194 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ribeira grande
# Processing record 195 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=fairbanks
# Processing record 196 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=zhigansk
# Processing record 197 | epernay
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=epernay
# Processing record 198 | gorontalo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=gorontalo
# Processing record 199 | san juan
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=san juan
# Processing record 200 | luanda
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=luanda
# Processing record 201 | kasli
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kasli
# Processing record 202 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=esperance
# Processing record 203 | ilhabela
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ilhabela
# Processing record 204 | tessalit
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=tessalit
# Processing record 205 | flin flon
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=flin flon
# Processing record 206 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=cidreira
# Processing record 207 | brownsville
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=brownsville
# Processing record 208 | faya
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=faya
# Processing record 209 | graneros
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=graneros
# Processing record 210 | namibe
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=namibe
# Processing record 211 | mongo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=mongo
# Processing record 212 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=meulaboh
# Processing record 213 | ust-ilimsk
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ust-ilimsk
# Processing record 214 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=georgetown
# Processing record 215 | wanaka
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=wanaka
# Processing record 216 | rodrigues alves
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=rodrigues alves
# Processing record 217 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=tilichiki
# Processing record 218 | teya
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=teya
# Processing record 219 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=umm lajj
# Processing record 220 | ondangwa
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ondangwa
# Processing record 221 | cao bang
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=cao bang
# Processing record 222 | jining
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=jining
# Processing record 223 | lasa
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=lasa
# Processing record 224 | poya
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=poya
# Processing record 225 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=mys shmidta
# Processing record 226 | itarema
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=itarema
# Processing record 227 | katakwi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=katakwi
# Processing record 228 | halalo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=halalo
# Processing record 229 | kadnikov
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kadnikov
# Processing record 230 | iralaya
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=iralaya
# Processing record 231 | rosario
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=rosario
# Processing record 232 | miri
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=miri
# Processing record 233 | nesher
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=nesher
# Processing record 234 | te anau
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=te anau
# Processing record 235 | kaeo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kaeo
# Processing record 236 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=turukhansk
# Processing record 237 | biak
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=biak
# Processing record 238 | copiapo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=copiapo
# Processing record 239 | kirakira
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kirakira
# Processing record 240 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=cayenne
# Processing record 241 | beyneu
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=beyneu
# Processing record 242 | zharkent
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=zharkent
# Processing record 243 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=bengkulu
# Processing record 244 | san luis
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=san luis
# Processing record 245 | asyut
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=asyut
# Processing record 246 | upington
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=upington
# Processing record 247 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=victoria
# Processing record 248 | henties bay
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=henties bay
# Processing record 249 | oistins
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=oistins
# Processing record 250 | dubbo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=dubbo
# Processing record 251 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=comodoro rivadavia
# Processing record 252 | suzu
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=suzu
# Processing record 253 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=praia da vitoria
# Processing record 254 | kamenka
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kamenka
# Processing record 255 | fryanovo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=fryanovo
# Processing record 256 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ketchikan
# Processing record 257 | juifang
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=juifang
# Processing record 258 | oussouye
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=oussouye
# Processing record 259 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=barentsburg
# Processing record 260 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=nikolskoye
# Processing record 261 | totma
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=totma
# Processing record 262 | simbahan
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=simbahan
# Processing record 263 | ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ahipara
# Processing record 264 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=grand gaube
# Processing record 265 | atar
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=atar
# Processing record 266 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=attawapiskat
# Processing record 267 | nadym
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=nadym
# Processing record 268 | jorhat
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=jorhat
# Processing record 269 | vao
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=vao
# Processing record 270 | port blair
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=port blair
# Processing record 271 | lolua
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=lolua
# Processing record 272 | sokolo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=sokolo
# Processing record 273 | salisbury
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=salisbury
# Processing record 274 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=portland
# Processing record 275 | toktogul
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=toktogul
# Processing record 276 | concepcion del uruguay
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=concepcion del uruguay
# Processing record 277 | paraiso
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=paraiso
# Processing record 278 | mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=mehamn
# Processing record 279 | flagstaff
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=flagstaff
# Processing record 280 | garwa
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=garwa
# Processing record 281 | balimo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=balimo
# Processing record 282 | grand centre
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=grand centre
# Processing record 283 | ambodifototra
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ambodifototra
# Processing record 284 | fernandez
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=fernandez
# Processing record 285 | tiarei
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=tiarei
# Processing record 286 | floro
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=floro
# Processing record 287 | san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=san quintin
# Processing record 288 | euclides da cunha
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=euclides da cunha
# Processing record 289 | arrecife
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=arrecife
# Processing record 290 | hovd
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=hovd
# Processing record 291 | russell
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=russell
# Processing record 292 | jurm
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=jurm
# Processing record 293 | viligili
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=viligili
# Processing record 294 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=yellowknife
# Processing record 295 | rockhampton
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=rockhampton
# Processing record 296 | goroka
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=goroka
# Processing record 297 | changtu
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=changtu
# Processing record 298 | stokmarknes
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=stokmarknes
# Processing record 299 | maragogi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=maragogi
# Processing record 300 | jacqueville
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=jacqueville
# Processing record 301 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kaitangata
# Processing record 302 | jiddah
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=jiddah
# Processing record 303 | mosquera
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=mosquera
# Processing record 304 | ghanzi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ghanzi
# Processing record 305 | tidore
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=tidore
# Processing record 306 | svit
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=svit
# Processing record 307 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=honningsvag
# Processing record 308 | richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=richards bay
# Processing record 309 | dingle
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=dingle
# Processing record 310 | potoru
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=potoru
# Processing record 311 | port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=port hardy
# Processing record 312 | harnoli
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=harnoli
# Processing record 313 | baisha
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=baisha
# Processing record 314 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=leningradskiy
# Processing record 315 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=alta floresta
# Processing record 316 | muzaffarabad
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=muzaffarabad
# Processing record 317 | buala
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=buala
# Processing record 318 | waipawa
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=waipawa
# Processing record 319 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=upernavik
# Processing record 320 | rocha
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=rocha
# Processing record 321 | mkushi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=mkushi
# Processing record 322 | aguas vermelhas
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=aguas vermelhas
# Processing record 323 | carballo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=carballo
# Processing record 324 | fort smith
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=fort smith
# Processing record 325 | puri
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=puri
# Processing record 326 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ostrovnoy
# Processing record 327 | monrovia
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=monrovia
# Processing record 328 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=batemans bay
# Processing record 329 | rawannawi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=rawannawi
# Processing record 330 | atbasar
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=hami
# Processing record 498 | canapi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=canapi
# Processing record 499 | kailua
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kailua
# Processing record 500 | black river
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=black river
# Processing record 501 | sereflikochisar
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=sereflikochisar
# Processing record 502 | itacarambi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=itacarambi
# Processing record 503 | las palmas
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=las palmas
# Processing record 504 | lusambo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=lusambo
# Processing record 505 | werda
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=werda
# Processing record 506 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=bolungarvik
# Processing record 507 | nushki
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=nushki
# Processing record 508 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=vila franca do campo
# Processing record 509 | aligudarz
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=aligudarz
# Processing record 510 | shawnee
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=shawnee
# Processing record 511 | isabela
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=isabela
# Processing record 512 | bati
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=bati
# Processing record 513 | haibowan
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=haibowan
# Processing record 514 | kadirli
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kadirli
# Processing record 515 | segovia
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=segovia
# Processing record 516 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=beringovskiy
# Processing record 517 | jardim
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=jardim
# Processing record 518 | grand island
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=grand island
# Processing record 519 | karratha
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=karratha
# Processing record 520 | acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=acapulco
# Processing record 521 | wladyslawowo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=wladyslawowo
# Processing record 522 | ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=ust-kuyga
# Processing record 523 | najran
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=najran
# Processing record 524 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=bandarbeyla
# Processing record 525 | nome
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=nome
# Processing record 526 | daye
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=daye
# Processing record 527 | berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=berlevag
# Processing record 528 | bereda
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=bereda
# Processing record 529 | at-bashi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=at-bashi
# Processing record 530 | kamalapuram
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kamalapuram
# Processing record 531 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=coahuayana
# Processing record 532 | nur
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=nur
# Processing record 533 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=virginia beach
# Processing record 534 | hearst
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=hearst
# Processing record 535 | chicama
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=chicama
# Processing record 536 | gloversville
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=gloversville
# Processing record 537 | the valley
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=the valley
# Processing record 538 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=berdigestyakh
# Processing record 539 | maarianhamina
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=maarianhamina
# Processing record 540 | kiama
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kiama
# Processing record 541 | cermik
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=cermik
# Processing record 542 | falealupo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=falealupo
# Processing record 543 | arlit
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=arlit
# Processing record 544 | prince george
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=prince george
# Processing record 545 | auraiya
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=auraiya
# Processing record 546 | champerico
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=champerico
# Processing record 547 | polunochnoye
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=polunochnoye
# Processing record 548 | mubi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=mubi
# Processing record 549 | libiaz
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=libiaz
# Processing record 550 | makaha
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=makaha
# Processing record 551 | novyy urengoy
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=novyy urengoy
# Processing record 552 | maceio
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=maceio
# Processing record 553 | amga
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=amga
# Processing record 554 | zhuanghe
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=zhuanghe
# Processing record 555 | chlorakas
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=chlorakas
# Processing record 556 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=broome
# Processing record 557 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=vardo
# Processing record 558 | skibbereen
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=skibbereen
# Processing record 559 | sataua
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=sataua
# Processing record 560 | astipalaia
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=astipalaia
# Processing record 561 | burgos
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=burgos
# Processing record 562 | preetz
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=preetz
# Processing record 563 | andenes
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=andenes
# Processing record 564 | namatanai
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=namatanai
# Processing record 565 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=svetlogorsk
# Processing record 566 | sola
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=sola
# Processing record 567 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=tumannyy
# Processing record 568 | harindanga
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=harindanga
# Processing record 569 | brokopondo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=brokopondo
# Processing record 570 | sakakah
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=sakakah
# Processing record 571 | san francisco
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=san francisco
# Processing record 572 | quirinopolis
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=quirinopolis
# Processing record 573 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=havre-saint-pierre
# Processing record 574 | yishui
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=yishui
# Processing record 575 | husavik
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=husavik
# Processing record 576 | shakiso
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=shakiso
# Processing record 577 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=plettenberg bay
# Processing record 578 | mujiayingzi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=mujiayingzi
# Processing record 579 | san felipe
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=san felipe
# Processing record 580 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=tomatlan
# Processing record 581 | blagoyevo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=blagoyevo
# Processing record 582 | miraflores
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=miraflores
# Processing record 583 | chapais
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=chapais
# Processing record 584 | omsukchan
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=omsukchan
# Processing record 585 | cairns
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=cairns
# Processing record 586 | morehead
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=morehead
# Processing record 587 | gat
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=gat
# Processing record 588 | boa vista
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=boa vista
# Processing record 589 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=pisco
# Processing record 590 | brigantine
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=brigantine
# Processing record 591 | biasca
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=biasca
# Processing record 592 | nha trang
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=nha trang
# Processing record 593 | malabo
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=malabo
# Processing record 594 | grand-santi
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=grand-santi
# Processing record 595 | rundu
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=rundu
# Processing record 596 | kunnamangalam
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=kunnamangalam
# Processing record 597 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=klaksvik
# Processing record 598 | meadow lake
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=meadow lake
# Processing record 599 | winslow
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=winslow
# Processing record 600 | aviles
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=aviles
# Processing record 601 | warrington
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=warrington
# Processing record 602 | churapcha
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=churapcha
# Processing record 603 | sogne
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=sogne
# Processing record 604 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=cockburn town
# Processing record 605 | vagur
# http://api.openweathermap.org/data/2.5/weather?appid=c594d1636fec442ff9e3f14087928218&units=imperial&q=vagur
# --------------------------------------------
# Data Processing Complete
# --------------------------------------------

# %%
weather_df =weather_df.dropna(how='any')
print(f"The data frame contains {len(weather_df['City'])} unique cities.")
# Out:
# The data frame contains 552 unique cities.

# %%
weather_df.head()
# Out:
#            City  Latitude  Longitude  Humidity  Max Temp  Cloudiness  \
# 0  saint george   37.1041  -113.5841      36.0     77.47           8
# 1       mataura  -46.1927   168.8643      69.0     47.46          32
# 2  port lincoln  -34.7333   135.8667      70.0     52.27           1
# 3      dedougou   12.4667    -3.4667      35.0     89.83          77
# 4    butaritari    3.0707   172.7902      73.0     81.88          83
#
#    Wind Speed          Date
# 0        3.11  1.635618e+09
# 1        3.85  1.635618e+09
# 2        7.18  1.635618e+09
# 3        5.17  1.635618e+09
# 4        6.04  1.635618e+09

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.to_csv('cities.csv',encoding = 'utf-8',index = False)
humid = dict(weather_df['Humidity'])

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
for k, v in humid.items():
    if v >= 100:
        print(k)
# Out:
# 137
# 190
# 392
# 399
# 473
# 538
# 552
# 601

# %%
weather_df['Humidity'][196]
# Out:
# 94.0

# %%
#  Get the indices of cities that have humidity over 100%.
weather_df = pd.read_csv('cities.csv')
weather_df.count()
# Out:
# City          552
# Latitude      552
# Longitude     552
# Humidity      552
# Max Temp      552
# Cloudiness    552
# Wind Speed    552
# Date          552
# dtype: int64

# %%
weather_df.head()
# Out:
#            City  Latitude  Longitude  Humidity  Max Temp  Cloudiness  \
# 0  saint george   37.1041  -113.5841      36.0     77.47           8
# 1       mataura  -46.1927   168.8643      69.0     47.46          32
# 2  port lincoln  -34.7333   135.8667      70.0     52.27           1
# 3      dedougou   12.4667    -3.4667      35.0     89.83          77
# 4    butaritari    3.0707   172.7902      73.0     81.88          83
#
#    Wind Speed          Date
# 0        3.11  1.635618e+09
# 1        3.85  1.635618e+09
# 2        7.18  1.635618e+09
# 3        5.17  1.635618e+09
# 4        6.04  1.635618e+09

# %%
weather_df.describe()
# Out:
#          Latitude   Longitude    Humidity    Max Temp  Cloudiness  Wind Speed  \
# count  552.000000  552.000000  552.000000  552.000000  552.000000  552.000000
# mean    19.186623   16.531511   70.376812   60.668895   58.945652    7.402083
# std     34.049504   89.163520   22.115504   22.903845   38.016292    5.215340
# min    -54.800000 -175.200000    8.000000  -14.010000    0.000000    0.000000
# 25%    -10.467675  -59.809800   60.000000   46.780000   20.000000    3.705000
# 50%     21.465300   18.992250   75.000000   65.695000   73.000000    6.200000
# 75%     49.808400   92.657525   88.000000   78.150000   98.000000    9.730000
# max     78.218600  179.316700  100.000000  101.230000  100.000000   35.050000
#
#                Date
# count  5.520000e+02
# mean   1.635618e+09
# std    9.843444e+01
# min    1.635618e+09
# 25%    1.635618e+09
# 50%    1.635618e+09
# 75%    1.635618e+09
# max    1.635618e+09

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
weather_df.loc[weather_df["Humidity"]>100]
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longitude, Humidity, Max Temp, Cloudiness, Wind Speed, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#scatterplot of Latitude vs. temperature
weather_df.plot('Latitude','Max Temp', kind='scatter', marker="o",)
plt.xlabel("Latitude")
plt.ylabel("Max Temp(F)")
plt.title("Latitude vs Max Temperature")

plt.savefig('Lat vs Max temp Scatterplot.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Scatter Plot of Latitude vs humidity
weather_df.plot('Latitude','Humidity', kind='scatter', marker="o",)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude vs Humidity")

plt.savefig('Lat vs Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Scatter plot of Latitude vs cloudiness
weather_df.plot('Latitude','Cloudiness', kind='scatter', marker="o",)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude vs Cloudiness")

plt.savefig('Lat vs Cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Scatterplot of Latitude vs Wind Speed
weather_df.plot('Latitude','Wind Speed', kind='scatter', marker="o",)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude vs Wind Speed")

plt.savefig('Lat vs Wind Speed.png')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#dataframe for Northern Hemisphere
weatherNorth_df=weather_df.loc[weather_df['Latitude']>=0]
weatherNorth_df
# Out:
#               City  Latitude  Longitude  Humidity  Max Temp  Cloudiness  \
# 0     saint george   37.1041  -113.5841      36.0     77.47           8
# 3         dedougou   12.4667    -3.4667      35.0     89.83          77
# 4       butaritari    3.0707   172.7902      73.0     81.88          83
# 6           ossora   59.2353   163.0719      93.0     17.94          84
# 8        grindavik   63.8424   -22.4338      87.0     39.67           0
# ..             ...       ...        ...       ...       ...         ...
# 547     warrington   53.3925    -2.5802      83.0     50.49           7
# 548      churapcha   62.0025   132.4325     100.0    -11.83          94
# 549          sogne   58.0833     7.8167      93.0     53.69         100
# 550  cockburn town   21.4612   -71.1419      65.0     84.16          40
# 551          vagur   61.4732    -6.8119      91.0     47.05         100
#
#      Wind Speed          Date
# 0          3.11  1.635618e+09
# 3          5.17  1.635618e+09
# 4          6.04  1.635618e+09
# 6          4.45  1.635618e+09
# 8          8.05  1.635618e+09
# ..          ...           ...
# 547        1.99  1.635618e+09
# 548        3.20  1.635618e+09
# 549       25.75  1.635618e+09
# 550        9.22  1.635618e+09
# 551       17.90  1.635618e+09
#
# [378 rows x 8 columns]

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Dataframe for Southern Hempisphere
weatherSouth_df=weather_df.loc[weather_df['Latitude']<0]
weatherSouth_df
# Out:
#                 City  Latitude  Longitude  Humidity  Max Temp  Cloudiness  \
# 1            mataura  -46.1927   168.8643      69.0     47.46          32
# 2       port lincoln  -34.7333   135.8667      70.0     52.27           1
# 5            rikitea  -23.1203  -134.9692      85.0     74.77          86
# 7             avarua  -21.2078  -159.7750      61.0     73.45         100
# 9             castro  -24.7911   -50.0119      75.0     71.35          51
# ..               ...       ...        ...       ...       ...         ...
# 518     quirinopolis  -18.4483   -50.4517      44.0     87.46          86
# 523  plettenberg bay  -34.0527    23.3716      92.0     59.38           1
# 531           cairns  -16.9167   145.7667      97.0     72.07          73
# 535            pisco  -13.7000   -76.2167      66.0     69.51          28
# 541            rundu  -17.9333    19.7667      35.0     83.26          96
#
#      Wind Speed          Date
# 1          3.85  1.635618e+09
# 2          7.18  1.635618e+09
# 5         21.70  1.635618e+09
# 7         16.87  1.635618e+09
# 9          7.90  1.635618e+09
# ..          ...           ...
# 518        7.52  1.635618e+09
# 523        2.44  1.635618e+09
# 531        4.83  1.635618e+09
# 535        8.99  1.635618e+09
# 541        3.87  1.635618e+09
#
# [174 rows x 8 columns]

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Linear Regression for Northern Hem Humidity vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(weatherNorth_df["Latitude"],weatherNorth_df["Humidity"])
regressionValues= (weatherNorth_df["Latitude"] * slope) + intercept
lineEQ= f"y ={slope:.2f}x + {intercept:.2f}"
print(lineEQ)

weatherNorth_df.plot('Latitude','Humidity', kind='scatter', marker="o",)
plt.plot(weatherNorth_df["Latitude"],regressionValues,"r-")
plt.annotate(lineEQ,(3,20),color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude vs Humidity")


plt.savefig('Latitude vs Humidity North.png')
plt.show()
# Out:
# y =0.35x + 58.51

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Southern Hem Humidity vs. Latitude 
(slope, intercept, rvalue, pvalue, stderr) = linregress(weatherSouth_df["Latitude"],weatherSouth_df["Humidity"])
regressionValues= (weatherSouth_df["Latitude"] * slope) + intercept
lineEQ= f"y ={slope:.2f}x + {intercept:.2f}"
print(lineEQ)

weatherSouth_df.plot('Latitude','Humidity', kind='scatter', marker="o",)
plt.plot(weatherSouth_df["Latitude"],regressionValues,"r-")
plt.annotate(lineEQ,(3,20),color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude vs Humidity")


plt.savefig('Latitude vs Humidity South.png')
plt.show()
# Out:
# y =-0.01x + 67.11

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Linear Regression for Northern Hem Cloudiness vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(weatherNorth_df["Latitude"],weatherNorth_df["Cloudiness"])
regressionValues= (weatherNorth_df["Latitude"] * slope) + intercept
lineEQ= f"y ={slope:.2f}x + {intercept:.2f}"
print(lineEQ)

weatherNorth_df.plot('Latitude','Cloudiness', kind='scatter', marker="o",)
plt.plot(weatherNorth_df["Latitude"],regressionValues,"r-")
plt.annotate(lineEQ,(3,20),color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude vs Cloudiness")


plt.savefig('Latitude vs Cloudiness North.png')
plt.show()
# Out:
# y =0.27x + 53.05

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Linear Regression for Southern Cloudiness vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(weatherSouth_df["Latitude"],weatherSouth_df["Cloudiness"])
regressionValues= (weatherSouth_df["Latitude"] * slope) + intercept
lineEQ= f"y ={slope:.2f}x + {intercept:.2f}"
print(lineEQ)

weatherSouth_df.plot('Latitude','Cloudiness', kind='scatter', marker="o",)
plt.plot(weatherSouth_df["Latitude"],regressionValues,"r-")
plt.annotate(lineEQ,(3,20),color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness)")
plt.title("Latitude vs Cloudiness")


plt.savefig('Latitude vs Cloudiness South.png')
plt.show()
# Out:
# y =0.86x + 68.42

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Linear Regression for Northern Hem Wind speed vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(weatherNorth_df["Latitude"],weatherNorth_df["Wind Speed"])
regressionValues= (weatherNorth_df["Latitude"] * slope) + intercept
lineEQ= f"y ={slope:.2f}x + {intercept:.2f}"
print(lineEQ)

weatherNorth_df.plot('Latitude','Wind Speed', kind='scatter', marker="o",)
plt.plot(weatherNorth_df["Latitude"],regressionValues,"r-")
plt.annotate(lineEQ,(3,20),color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude vs Wind Speed")


plt.savefig('Latitude vs Wind Speed North.png')
plt.show()
# Out:
# y =0.04x + 5.44

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Linear Regression for Southern Hem Humidity vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(weatherSouth_df["Latitude"],weatherSouth_df["Wind Speed"])
regressionValues= (weatherSouth_df["Latitude"] * slope) + intercept
lineEQ= f"y ={slope:.2f}x + {intercept:.2f}"
print(lineEQ)

weatherSouth_df.plot('Latitude','Wind Speed', kind='scatter', marker="o",)
plt.plot(weatherSouth_df["Latitude"],regressionValues,"r-")
plt.annotate(lineEQ,(3,20),color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude vs Wind Speed")


plt.savefig('Latitude vs Wind Speed South.png')
plt.show()
# Out:
# y =-0.05x + 6.96

# %%
# Linear Regression for Northern Hem Temp vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(weatherNorth_df["Latitude"],weatherNorth_df["Max Temp"])
regressionValues= (weatherNorth_df["Latitude"] * slope) + intercept
lineEQ= f"y ={slope:.2f}x + {intercept:.2f}"
print(lineEQ)

weatherNorth_df.plot('Latitude','Max Temp', kind='scatter', marker="o",)
plt.plot(weatherNorth_df["Latitude"],regressionValues,"r-")
plt.annotate(lineEQ,(3,20),color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp(F)")
plt.title("Latitude vs Max Temperature")


plt.savefig('Latitude vs Max temp North.png')
plt.show()
# Out:
# y =-1.01x + 94.52

# %%
# Linear Regression for Southern Hem MAx Temp vs Latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(weatherSouth_df["Latitude"],weatherSouth_df["Max Temp"])
regressionValues= (weatherSouth_df["Latitude"] * slope) + intercept
lineEQ= f"y ={slope:.2f}x + {intercept:.2f}"
print(lineEQ)

weatherSouth_df.plot('Latitude','Max Temp', kind='scatter', marker="o",)
plt.plot(weatherSouth_df["Latitude"],regressionValues,"r-")
plt.annotate(lineEQ,(3,20),color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp(F)")
plt.title("Latitude vs Max Temperature")


plt.savefig('Latitude vs Max temp South.png')
plt.show()
# Out:
# y =0.65x + 86.19
